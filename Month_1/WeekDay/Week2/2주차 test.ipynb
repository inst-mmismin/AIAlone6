# %%
cd /content/drive/MyDrive/AIStandAlone/Group_6/StandAlone_Group6_ShareFolder/LiveCode/Month_1/WeekDay
# Out:
# /content/drive/MyDrive/AIStandAlone/Group_6/StandAlone_Group6_ShareFolder/LiveCode/Month_1/WeekDay

# %%
# !python test.py
# Out:
# hello world

# %%
# !python test.py
# Out:
# hello world!!!!!!!

# %%
cd /content/drive/MyDrive/AIStandAlone/Group_6/StandAlone_Group6_ShareFolder/LiveCode/Month_1/WeekDay/Week2
# Out:
# /content/drive/MyDrive/AIStandAlone/Group_6/StandAlone_Group6_ShareFolder/LiveCode/Month_1/WeekDay/Week2

# %%
# !python vscode2colab_test.py
# Out:
# ...
# 100% 9912422/9912422 [00:00<00:00, 111025479.33it/s]
# Extracting ../../data/mnist/MNIST/raw/train-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 93541076.31it/s]
# Extracting ../../data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 54637820.43it/s]
# Extracting ../../data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 19518984.39it/s]
# Extracting ../../data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw
#
# 0/5 , 0 step | Loss : 2.2873
# 0/5 , 100 step | Loss : 0.4954
# 0/5 , 200 step | Loss : 0.1714
# 0/5 , 300 step | Loss : 0.2411
# 0/5 , 400 step | Loss : 0.3216
# 0/5 , 500 step | Loss : 0.3093
# 1/5 , 0 step | Loss : 0.2705
# 1/5 , 100 step | Loss : 0.3548
# 1/5 , 200 step | Loss : 0.2406
# 1/5 , 300 step | Loss : 0.2777
# 1/5 , 400 step | Loss : 0.3870
# 1/5 , 500 step | Loss : 0.3172
# ...
